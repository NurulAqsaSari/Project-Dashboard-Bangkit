# %%
#Gathering Data
#Mengimpor library yang dibutuhkan

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#gathering data
#Input data

data = pd.read_csv('C:/Users/asus/Downloads/Bike-sharing-dataset/day.csv')
data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
#Assesing Data
#menampilkan 5 data teratas

data.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
#Assesing Data
#menampilkan 5 data terbawah

data.tail()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# ...

# %%
#Assesing Data
#menampilkan ukuran data

data.shape
# Out:
# (731, 16)

# %%
#Assesing Data
#Melihat info data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
#Assesing Data
#mengecek missing value 

df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
#explor data

data.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
#Assesing Data
#mengecek duplikasi data

df.duplicated().sum()
# Out:
# 0

# %%
#cleaning data
#menampilkan data yang akan dianalisis saja

day = data[['season', 'mnth', 'weathersit', 'cnt']]
day
# Out:
#      season  mnth  weathersit   cnt
# 0         1     1           2   985
# 1         1     1           2   801
# 2         1     1           1  1349
# 3         1     1           1  1562
# 4         1     1           1  1600
# ..      ...   ...         ...   ...
# 726       1    12           2  2114
# 727       1    12           2  3095
# 728       1    12           2  1341
# 729       1    12           1  1796
# 730       1    12           2  2729
#
# [731 rows x 4 columns]

# %%
#Assesing Data
#menampilkan 5 data teratas untuk dianalisis

day.head()
# Out:
#    season  mnth  weathersit   cnt
# 0       1     1           2   985
# 1       1     1           2   801
# 2       1     1           1  1349
# 3       1     1           1  1562
# 4       1     1           1  1600

# %%
#Assesing Data
#menampilkan 5 data terbawah untuk dianalisis

day.tail()
# Out:
#      season  mnth  weathersit   cnt
# 726       1    12           2  2114
# 727       1    12           2  3095
# 728       1    12           2  1341
# 729       1    12           1  1796
# 730       1    12           2  2729

# %%
#Assesing Data
#menampilkan ukuran dari data yang akan dianalisis

day.shape
# Out:
# (731, 4)

# %%
#Assesing Data
#menampilkan info data yang akan dianalisis

day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      731 non-null    int64
#  1   mnth        731 non-null    int64
#  2   weathersit  731 non-null    int64
#  3   cnt         731 non-null    int64
# dtypes: int64(4)
# memory usage: 23.0 KB

# %%
#Assesing Data
#mengecek missing value dari data yang dianalisis

day.isnull().sum()
# Out:
# season        0
# mnth          0
# weathersit    0
# cnt           0
# dtype: int64

# %%
#Assesing Data
#mengecek duplikasi data dari data yang di analisis

day.duplicated().sum()
# Out:
# 0

# %%
#eksplor data

day.describe()
# Out:
#            season        mnth  weathersit          cnt
# count  731.000000  731.000000  731.000000   731.000000
# mean     2.496580    6.519836    1.395349  4504.348837
# std      1.110807    3.451913    0.544894  1937.211452
# min      1.000000    1.000000    1.000000    22.000000
# 25%      2.000000    4.000000    1.000000  3152.000000
# 50%      3.000000    7.000000    1.000000  4548.000000
# 75%      3.000000   10.000000    2.000000  5956.000000
# max      4.000000   12.000000    3.000000  8714.000000

# %%
#ekxplor data

datab = day.copy()

# Melakukan mapping untuk setiap variabel kategorikal
datab['weathersit'] = datab['weathersit'].map({1: 'Cerah', 2: 'Berkabut', 3: 'Hujan Ringan', 4: 'Hujan Lebat'})
datab['season'] = datab['season'].map({1: 'springer', 2: 'summer', 3: 'fall', 4: 'winter'})

# Mengatur urutan kelas
weathersit_order = ['Cerah', 'Berkabut', 'Hujan Ringan', 'Hujan Lebat']
season_order = ['springer', 'summer', 'fall', 'winter']

# Membuat pivot tabel untuk rata-rata jumlah peminjaman sepeda terhadap variabel cuaca dan musim
pivot_weathersit = datab.groupby(by=["weathersit"]).agg({
    "cnt": "mean"
}).reindex(weathersit_order, fill_value=0).reset_index()
pivot_season = datab.groupby(by=["season"]).agg({
    "cnt": "mean"
}).reindex(season_order, fill_value=0).reset_index()

# Menampilkan pivot tabel
pd.options.display.float_format = '{:.2f}'.format
print("Rata-rata jumlah peminjaman sepeda terhadap keadaan cuaca :")
print(pivot_weathersit.to_string(index=False))
print("\n===============================================\n")
print("Rata-rata jumlah peminjaman sepeda terhadap musim :")
print(pivot_season.to_string(index=False))
# Out:
# Rata-rata jumlah peminjaman sepeda terhadap keadaan cuaca :
#   weathersit     cnt
#        Cerah 4876.79
#     Berkabut 4035.86
# Hujan Ringan 1803.29
#  Hujan Lebat    0.00
#
# ...
#
# Rata-rata jumlah peminjaman sepeda terhadap musim :
#   season     cnt
# springer 2604.13
#   summer 4992.33
#     fall 5644.30
#   winter 4728.16

# %%
#eksplor data

data.groupby(by="weekday").cnt.nunique()
# Out:
# weekday
# 0    104
# 1    104
# 2    104
# 3    103
# 4    103
# 5    104
# 6    102
# Name: cnt, dtype: int64

# %%
#Viusalisasi dan eksplanatory data
#Hubungan antara musim dan jumlah sewa sepeda harian

seasonal_data = day.groupby('season')['cnt'].mean()
season_names = ['springer', 'summer', 'fall', 'winter']
colors = ["pink", "pink", "darkcyan", "pink"]
sns.barplot(season_names, seasonal_data, palette = colors)
plt.xlabel('Musim')
plt.ylabel('Rata-rata Jumlah Sewa Sepeda Harian')
plt.title('Pengaruh Musim terhadap Jumlah Sewa Sepeda Harian')
plt.show()
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Berdasarkan grafik diatas dapat dilihat bahwa jumlah sewa sepeda lebih banyak pada musim gugur(Fall)

# %%
#Viusalisasi dan eksplanatory data
#perbedaan pola berdasarkan bulan dalam jumlah sewa sepeda harian

sns.set_style("darkgrid")
plt.figure(figsize=(12, 6))
sns.lineplot(x="mnth", y="cnt", data=day, ci=None, color = "purple")
plt.title("Pola Jumlah Sewa Sepeda Harian Berdasarkan Bulan")
plt.xlabel("Bulan")
plt.ylabel("Jumlah Sewa Sepeda Harian")
plt.show()

# %% [markdown]
# berdasarkan line chart di atas dapat disimpulkan bahwa dari bulan jumlah sewa sepeda meningkat pada bulan 6 dan 9.

# %%
#Viusalisasi dan eksplanatory data
#pengaruh cuaca (weathersit) terhadap jumlah sewa sepeda harian

plt.figure(figsize=(10, 6))
sns.boxplot(x="weathersit", y="cnt", data=day)
plt.title("Pengaruh Weathersit Terhadap Jumlah Sewa Sepeda Harian")
plt.xlabel("Weathersit")
plt.ylabel("Jumlah Sewa Sepeda Harian")
plt.show()

# %% [markdown]
# Berdasarkan boxplot di atas dapat disimpulkan bahwa jumlah sewa sepeda mengingkat ketika cuaca Cerah, Sedikit awan, Berawan sebagian, Berawan sebagian.

# %% [markdown]
# Conclusion

# %% [markdown]
# 1.  Bagaimana hubungan antara musim dan jumlah sewa sepeda harian ?
# jawab : Berdasarkan analisis data di atas yaitu berdasarkan bar chart dapat dilihat bahwa jumlah sewa sepeda lebih banyak pada musim gugur(Fall) yaitu rata-ratanya sekitar 5644,30.

# %% [markdown]
# 2. Apakah ada pola berdasarkan waktu (bulan, jam)dalam jumlah sewa sepeda harian?
# Jawab : Berdasarkan analisis data di atas yaitu berdasarkan line chart dapat dilihat bahwa dari bulan jumlah sewa sepeda meningkat pada bulan 6 dan 9.

# %% [markdown]
# 3. Bagaimana pengaruh cuaca (weathersit) terhadap jumlah sewa sepeda harian?
# Jawab : Berdasarkan analisis data di atas yaitu berdasarkan boxplot dapat dilihat bahwa jumlah sewa sepeda mengingkat ketika cuaca Cerah, Sedikit awan, Berawan sebagian, Berawan sebagian.
